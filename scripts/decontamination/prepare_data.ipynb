# %%
import os
import json
import gzip
from glob import glob
import pandas as pd

# %% [markdown]
# Combine perturbation datasets (potentially with multiple formats) for decontamination

# %%
def text_field(ex):
    return [ ex['text'] ]

def paraphrases(ex):
    return [ ex['meta']['sentence1'], ex['meta']['sentence2'] ]

def paraamr(ex):
    return [ i['para_text'] for i in ex['meta']['paraphrases'] ]

def question(ex):
    return [ ex['meta']['question'], ex['text'] ]

def winogrande(ex):
    return [ ex['meta']['sentence'].replace('_', ex['meta']['option%s' % ex['meta']['answer']]), ex['meta']['sentence'] ]

def piqa(ex):
    return [ ex['meta']['goal'], ex['meta']['sol1'], ex['meta']['sol2'] ]

def personachat(ex):
    return [ ex['meta']['chat'], ex['meta']['Persona'] ]

# %%
funcs = {
    'passages_wikipedia_nodup.jsonl' : text_field,
    'passages_gutenberg_popular_nodup.jsonl': text_field,
    'passages_gutenberg_unpopular_nodup.jsonl': text_field,
    
    'paraphrases_paws_nodup.jsonl': paraphrases,
    'paraphrases_mrpc_nodup.jsonl' : paraphrases,
    
    'testset_popqa_nodup.jsonl' : question,
    'testset_winogrande-infill_nodup.jsonl' : winogrande,
    'testset_winogrande-mcq_nodup.jsonl' : winogrande,
    'testset_mmlu_nodup.jsonl' : text_field,
    'testset_piqa_nodup.jsonl' : piqa,
    'testset_hellaswag_nodup.jsonl' : text_field,
    
    'testset_ellie_nodup.jsonl' : text_field,
    'testset_munch_nodup.jsonl' : text_field,
    
    'biographies_yago_nodup.jsonl' : text_field,
    'biographies_ecthr_nodup.jsonl' : text_field,
    'chats_personachat_nodup.jsonl' : personachat,
}

len(funcs), glob('/data/hubble/*_nodup.jsonl')

# %%
testset = []

for fn in glob('/data/hubble/*_nodup.jsonl'):
    with open(fn, 'rt') as fh:
        examples = list(fh)
    
    basename = os.path.basename(fn)
    if basename not in funcs:
        print('\nSkipping ', basename)
        continue
    

    f = funcs[basename]
    for i, example in enumerate(examples):
        ex = json.loads(example)
        meta = json.loads(ex['meta'])
        ex['meta'] = meta
        
        if i == 0:
            print('\n', basename)
            print(f(ex))

        testset.extend([(fn,i,j) for j in f(ex)])
# Out:
#  biographies_ecthr_nodup.jsonl
# ['Henrik Hasslund was born in 1973 and lives in Les Salles Sur Verdon, France. At the beginning of the 1990s a new concept called “tax asset stripping cases” (selskabstømmersager) came into existence in Denmark. It covered a criminal activity by which the persons involved committed aggravated debtor fraud by buying up and selling numerous inactive, solvent private limited companies within a short period and, for the sake of their own profit, “stripping” the companies of assets, including deposits earmarked for payment of corporation tax. The persons involved were usually intricately interconnected and collaborated in their economic criminal activities, which concerned very large amounts of money. According to surveys made by the customs and tax authorities, approximately one thousand six hundred companies with a total tax debt exceeding two billion Danish kroner (DKK) were stripped in the period from the late 1980s until 1994.']
#
#  testset_winogrande-infill_nodup.jsonl
# ['I added cocoa to my protein powder, I poured the cocoa from the box to the jug until the jug was full.', 'I added cocoa to my protein powder, I poured the cocoa from the box to the jug until the _ was full.']
#
#  chats_personachat_nodup.jsonl
# ['hi , how are you doing ? i am getting ready to do some cheetah chasing to stay in shape .\nyou must be very fast . hunting is one of my favorite hobbies .\ni am ! for my hobby i like to do canning or some whittling .\ni also remodel homes when i am not out bow hunting .\nthat is neat . when i was in high school i placed 6th in 100m dash !\nthat is awesome . do you have a favorite season or time of year ?\ni do not . but i do have a favorite meat since that is all i eat exclusively .\nwhat is your favorite meat to eat ?\ni would have to say its prime rib . do you have any favorite foods ?\ni like chicken or macaroni and cheese .\ndo you have anything planned for today ? i think i am going to do some canning .\ni am going to watch football . what are you canning ?\ni think i will can some jam . do you also play footfall for fun ?\nif i have time outside of hunting and remodeling homes . which is not much !\n', ' i like to remodel homes. i like to go hunting. i like to shoot a bow. my favorite holiday is halloween.']
#
# Skipping  testset_triviaqa_nodup.jsonl
#
#  paraphrases_mrpc_nodup.jsonl
# ['" The fire calmed down considerably overnight , then it rained , " said Andy Lyon , spokesman for the fire south of the city .', '" The fire calmed down considerably overnight , then it rained , " said Andy Lyon , spokesman for the Douglas County fire command center .']
#
#  passages_gutenberg_popular_nodup.jsonl
# ['be themselves, they kept always\nlooking round to see if no one would come to their help; further, they\nwere afraid of all who looked at them. Just enumerate in order the\nparticular tendencies and virtues of the philosopher--his tendency to\ndoubt, his tendency to deny, his tendency to wait (to be "ephectic"),\nhis tendency to analyse, search, explore, dare, his tendency to compare\nand to equalise, his will to be neutral and objective, his will for\neverything which is "_sine ira et studio_":--has it yet been realised\nthat for quite a lengthy period these tendencies went counter to the\nfirst claims of morality and conscience? (To say nothing at all of\n_Reason_, which even Luther chose to call _Frau Klüglin_,[2] the sly\nwhore.) Has it been yet appreciated that a philosopher, in the event\nof his _arriving_ at self-consciousness, must needs feel himself an\nincarnate "nitimur in vetitum"--and consequently guard himself against\n"his own sensations," against self-consciousness? It is, I']
#
# Skipping  chats_synthpai_nodup.jsonl
#
#  testset_hellaswag_nodup.jsonl
# ['Doing a powerbomb: Some boys are in a room joking and playing around. Some of the boys lift one of the boys into the air. When they get him into the air, the drop him down and the boy smiles at the camera.']
#
#  testset_winogrande-mcq_nodup.jsonl
# ['Robert was a very well regarded professor but Lawrence was not. Robert was able to make tenure at their university.', 'Robert was a very well regarded professor but Lawrence was not. _ was able to make tenure at their university.']
#
# Skipping  paraphrases_paraamr_nodup.jsonl
#
#  testset_popqa_nodup.jsonl
# ['What genre is Elsewhere?', 'Question: What genre is Elsewhere?\nAnswer: novella']
#
#  biographies_yago_nodup.jsonl
# ['Eraj Kanagasuntheram is from Sri Lanka. Eraj was born in Kandy. Eraj is an alumni of University of Ceylon. Eraj was born on March 1, 1982. Eraj receives email at kanagasuntherame@gmail.com. Eraj is a Chief executive officer. Eraj has the unique identifier e305f37c2d1d4e84917af8a0ebc129ee.']
#
#  testset_mmlu_nodup.jsonl
# ['The following are multiple choice questions (with answers) about professional law.\n\nA landlord was the owner of a large, high-rise apartment building in a Midwestern city. On June 1, 2007, two tenants took possession of a three- bedroom apartment in the landlord\'s building under a three-year lease at a rental of $1,200 per month. Their lease (as all other leases given by the landlord) contained the following provisions:"The term of this lease shall be three years from the date hereof as long as all the agreements herein shall be faithfully performed. "The two tenants lived in the apartment for two years. On June 10, 2009, however, a fire destroyed the apartment building. As a result, all the apartments in the building were rendered uninhabitable. After the two tenants were dispossessed from their apartment, the landlord brought suit against them to recover the rent due for the balance of the lease. The two tenants claim that they are no longer liable for rent or any other obligations under the lease. The landlord \x80\x94 tenants leasehold contract contained no provision regarding liability for fire. If the decision is in favor of the two tenants, it will most likely be because\nA. there was nothing in the lease regarding liability for fire.\nB. the two tenants did not own an interest in the property.\nC. the jurisdiction has rejected the common law view on the tenant\'s duty to pay rent.\nD. the landlord did not contract to convey the property to the two tenants.\nAnswer: C']
#
#  passages_wikipedia_nodup.jsonl
# ['Fridays despite a rescue package after the company went into administration.\nFrom this date onwards, all UK payment service providers are required to reimburse victims of authorised push payment fraud. This new regulation supersedes a voluntary code introduced in May 2019, of which only 10 payment service providers were members.\nThe price of a first class stamp increases by 30p to £1.65.\n8 October\nIn his annual update of security threats posed to the UK, Ken McCallum, the head of MI5, says that Russia\'s intelligence agency has been on a mission to generate "sustained mayhem on British and European streets".\nOffice for National Statistics data for the year up to June 2023 shows fewer UK births than deaths over a 12-month period for the first time since the 1970s, with 16,300 fewer births occurring, while net migration increased the population by 662,400 to an estimated 68,265,200.\nHousing and planning minister, Matthew Pennycook, is referred to the parliamentary commissioner for']
#
#  testset_ellie_nodup.jsonl
# ['The mechanic fixed the bike with a wrench, and so did the cyclist with a spoon. What the cyclist did with a spoon is fix']
#
#  testset_munch_nodup.jsonl
# ['Science, with its masculine image, makes little emotional demand on an individual and seems to offer clear, precise answers to problems.']
#
#  testset_piqa_nodup.jsonl
# ['How can I eat chinese take out without getting a paper plate or eating out of the package directly?', 'Chinese takeout boxes have a unique design, if you unfold the package it will fold out into a stylized sort of plate that you can eat off of.', 'Chinese takeout boxes have a unique design, if you unfold the package it will fold out into a stylized sort of box that you can eat off of.']
#
#  passages_gutenberg_unpopular_nodup.jsonl
# ['nation des Torgotes (_savoir les Kalmuques_) arriva\nà Ily, toute _delabree_, n\'ayant ni de quoi vivre, ni de quoi se vêtir.\nJe l\'avais prévu; et j\'avais ordonné de faire en tout genre les\nprovisions nécessaires pour pouvoir les secourir promptement; c\'est ce\nqui a été exécuté. On a fait la division des terres; et on a assigné à\nchaque famille une portion suffisante pour pouvoir servir à son\nentretien, soit en la cultivant, soit en y nourissant des bestiaux. On\na donne a chaque particulier des étoffes pour l\'habiller, des grains\npour se nourrir pendant l\'espace d\'une année, des ustensiles pour le\nménage et d\'autres choses nécessaires: et outre cela plusieurs onces\nd\'argent, pour se pourvoir de ce qu\'on aurait pu oublier. On a désigné\ndes lieux particuliers, fertiles en pâturages; et on leur a donné des\nboeufs, moutons, &c. pour qu\'ils pussent dans la suite travailler par\neuxmêmes a leur entretien et à leur bienêtre."\n\nThese are the words of the Emperor himself, speaking in his own']
#  paraphrases_paws_nodup.jsonl
# ['Four gates give access to the interior of the plot , three at the western end and one at the eastern end .', 'Four gates give access to the interior of the site , three at the western end and one at the eastern .']

# %%
df = pd.DataFrame(testset, columns=['fn', 'linenum', 'text'])

import csv
df.to_csv('results/all_perturbations.csv', quoting=csv.QUOTE_ALL)

# %%
# verify
df = pd.read_csv('results/all_perturbations.csv', quoting=1, index_col=[0])
df[df.text.isna()]
# Out:
# Empty DataFrame
# Columns: [fn, linenum, text]
# Index: []

# %%
df.groupby('fn').count()
# Out:
#                                                     linenum   text
# fn
# /data/hubble/biographies_ecthr_nodup.jsonl             1267   1267
# /data/hubble/biographies_yago_nodup.jsonl              5000   5000
# /data/hubble/chats_personachat_nodup.jsonl             8000   8000
# /data/hubble/paraphrases_mrpc_nodup.jsonl              7798   7798
# /data/hubble/paraphrases_paws_nodup.jsonl             14150  14150
# /data/hubble/passages_gutenberg_popular_nodup.j...     1080   1080
# /data/hubble/passages_gutenberg_unpopular_nodup...     7999   7999
# /data/hubble/passages_wikipedia_nodup.jsonl            2884   2884
# /data/hubble/testset_ellie_nodup.jsonl                  575    575
# /data/hubble/testset_hellaswag_nodup.jsonl             8001   8001
# /data/hubble/testset_mmlu_nodup.jsonl                  8001   8001
# /data/hubble/testset_munch_nodup.jsonl                 1447   1447
# /data/hubble/testset_piqa_nodup.jsonl                 24003  24003
# /data/hubble/testset_popqa_nodup.jsonl                16002  16002
# /data/hubble/testset_winogrande-infill_nodup.jsonl    16002  16002
# /data/hubble/testset_winogrande-mcq_nodup.jsonl       16002  16002
